# %%
from trader_factory import build_active_IBridgePy_plus
from IBridgePy.IbridgepyTools import symbol
from IBridgePy.OrderTypes import LimitOrder, StopOrder

# %%
t = build_active_IBridgePy_plus('DU1868499')  # t is the IBridgePy plus object
# Out:
# Try brokerClient IBinsync port=7496
# port=7496 is correct and set port to userConfig.brokerClientConfig.IB_CLIENT
# Connected to IB is successful using port=7496
# ##    ACCOUNT Balance  DU1868499  ##
# CASH=1214987.01
# portfolio_value=1217882.76
# positions_value=0.0
# ##    NO ANY POSITION    ##
# ##    NO any order    ##

# %%
t.display_all()  # display account information

# %%
# Retrieve historical data of SPY, daily bar, and go back 5 days.
t.request_historical_data(symbol('SPY'), '1 day', '5 D')

# %%
# Show real time ask price of a FOREX EURUSD. Try this one when market is open to see a valid price
t.show_real_time_price(symbol('CASH,EUR,USD'), 'ask_price')
# Out:
# broker_client_factory.BrokerClient::request_data: EXIT, the following requestRecord failed
# {reqId=72,status=Submitted,reqType=reqMktData,followUp=True,waitForFeedbackInSeconds=30,param={security:CASH,IDEALPRO,IDEALPRO,EUR,USD,genericTickList:101,snapshot:False,tickTypeClientAsked:None,}}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Show real time ask price of a FOREX EURUSD. Try this one when market is open to see a valid price
# ----> 2 t.show_real_time_price(symbol('CASH,EUR,USD'), 'ask_price')
#
# File ~/Documents/Yellowstone/IBridgePy/Trader.py:668, in Trader.show_real_time_price(self, security, param, followUp)
#     666 # self.validator.showRealTimePriceValidator.validate(security, adj_param)
#     667 self._dataProviderService.add_exchange_primaryExchange_to_security(security)
# --> 668 return self._dataProviderService.get_real_time_price(security, self.tick_type_mapper[param], followUp)
#
# File ~/Documents/Yellowstone/broker_service_factory/BrokerService_web.py:66, in WebApi.get_real_time_price(self, security, tickType, followUp)
#      64 def get_real_time_price(self, security, tickType, followUp=True):  # return real time price
#      65     self._log.notset(__name__ + '::get_real_time_price: security=%s tickType=%s' % (security.full_print(), tickType))
# ---> 66     self._submit_request_after_checking_cache(ReqMktData(security, followUp=followUp))
#      67     return self._get_real_time_price_from_dataFromServer(security, tickType)
#
# File ~/Documents/Yellowstone/broker_service_factory/BrokerService_web.py:58, in WebApi._submit_request_after_checking_cache(self, request, freshness_in_microseconds)
#      56 if not self._request_recorder.hasRecentRequest(request, freshness_in_microseconds):
#      57     self._log.debug(__name__ + '::_submit_request_after_checking_cache: submit_requests')
# ---> 58     self.submit_requests(request)
#      59     return True
#      60 else:
#
# File ~/Documents/Yellowstone/broker_service_factory/BrokerService.py:345, in BrokerService.submit_requests(self, *args)
#     339 """
#     340
#     341 :param args: broker_client_factory::BrokerClientDefs::Request
#     342 :return: a list of reqId !!!
#     343 """
#     344 self._log.notset(f'{__name__}::submit_requests: args={args}')
# --> 345 return self._brokerClient.request_data(*args)
#
# File ~/Documents/Yellowstone/broker_client_factory/BrokerClient.py:397, in BrokerClientBase.request_data(self, *args)
#     395                 raise LostHeartBeat()
#     396         self.e_disconnect()
# --> 397         raise RuntimeError(f'{self.name} server did not respond to the request at all.\nThe current time={dt.datetime.now()} \nHint 1: Restart TWS or IB Gateway. \nHint 2: Please close ALL IBridgePy instances if any and restart. \nHint 3: Maybe the market is closed? Is the brokers server on maintenance? Consider trying it later.')
#     398     self.processMessagesWrapper(self._timeGenerator.get_current_time())
#     399 self._log.debug(__name__ + '::request_data: All responses are received')
#
# RuntimeError: IBinsync server did not respond to the request at all.
# The current time=2023-09-22 15:18:32.353032
# Hint 1: Restart TWS or IB Gateway.
# Hint 2: Please close ALL IBridgePy instances if any and restart.
# Hint 3: Maybe the market is closed? Is the brokers server on maintenance? Consider trying it later.

# %%
# Show 'NetLiquidation' of the account
t.show_account_info('NetLiquidation')
# Out:
# 1217882.76

# %%
# Buy 100 share of FOREX EURUSD
t.order(symbol('CASH,EUR,USD'), 100)

# %%
# Display all positions in the account
t.get_all_positions()
# Out:
# {}

# %%
# Close all positions of FOREX EURUSD
t.order_target(symbol('CASH,EUR,USD'), 0)

# %%
# Place a limit price order
t.order(symbol('SPY'), 10, LimitOrder(limit_price=99.90))

# %%
# Display all open orders in the account
t.get_all_orders()
# Out:
# {}

# %%
# Look for the orderId and try to cancel an open order
# For example, 'ib61' is the orderId
t.cancel_order('ib61')

# %%
t.disconnect()
